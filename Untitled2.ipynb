# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,5,11)
y = x ** 2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])
axes1.plot(x,y)
axes1.set_title("LARGER PLOT")
axes2.plot(y,x)
axes2.set_title("SMALLER PLOT")
# Out:
# Text(0.5, 1.0, 'SMALLER PLOT')

# %%
fig, axes = plt.subplots(nrows=1,ncols=1)
print(type(axes))
plt.tight_layout()
axes.plot(x,y)
# Out:
# <class 'matplotlib.axes._subplots.AxesSubplot'>

# %%
fig, axes = plt.subplots(nrows=3,ncols=3)
print(type(axes))
plt.tight_layout()
print(axes)
# axes.plot(x,y)
# Out:
# <class 'numpy.ndarray'>
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x0000017A51A85348>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000017A519DBD08>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000017A512DD548>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x0000017A51987B88>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000017A51971848>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000017A5133A308>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x0000017A512FA088>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000017A51588348>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000017A51893548>]]

# %%
fig, axes = plt.subplots(nrows=1,ncols=2)

# for current_ax in axes:
#     current_ax.plot(x,y)
axes[0].plot(x,y)
a
axes[1].plot(y,x)
