# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,5,11)
y = x ** 2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])
axes1.plot(x,y)
axes1.set_title("LARGER PLOT")
axes2.plot(y,x)
axes2.set_title("SMALLER PLOT")
# Out:
# Text(0.5, 1.0, 'SMALLER PLOT')

# %%
fig, axes = plt.subplots(nrows=1,ncols=1)
print(type(axes))
plt.tight_layout()
axes.plot(x,y)
# Out:
# <class 'matplotlib.axes._subplots.AxesSubplot'>

# %%
fig, axes = plt.subplots(nrows=3,ncols=3)
print(type(axes))
plt.tight_layout()
print(axes)
# axes.plot(x,y)
# Out:
# <class 'numpy.ndarray'>
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DE5474DCC8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000001DE54793988>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000001DE547CF108>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x000001DE54805A88>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000001DE5483F848>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000001DE54874A08>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x000001DE548AEBC8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000001DE548E6E48>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000001DE54917548>]]

# %%
fig, axes = plt.subplots(nrows=1,ncols=2)

# for current_ax in axes:
#     current_ax.plot(x,y)
axes[0].plot(x,y)
axes[0].set_title("first plot")
axes[1].plot(y,x)
axes[1].set_title("second plot")
plt.tight_layout()

# %% [markdown]
# Figure SIze and DPI

# %%
fig = plt.figure(figsize=(8,2),dpi=100)
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(8,2),dpi=100)
axes[0].plot(x,y)
axes[1].plot(y,x)
plt.tight_layout()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_title('Title')
ax.set_ylabel('Y')
ax.set_xlabel('X')

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='X Squared')
ax.plot(x,x**3,label='X Cubed')
# ax.legend(loc=0)
ax.legend(loc=(0.1,0.1))

# %%
fig.savefig('my_pic.png',dpi=500)
